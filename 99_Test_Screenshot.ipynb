# %% [markdown]
# # Test if screenshots are saved and stored properly

# %% [markdown]
# ## This is a black box
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## This is a gray box
# ![image.png](attachment:image.png)
